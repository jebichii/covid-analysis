# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings(action="ignore")

# %%
df = pd.read_csv("owid-covid-data.csv",index_col=0)
# set seed for reproducibility
df.sample(10)
# Out:
#               continent     location        date  total_cases  new_cases  \
# iso_code
# PSE                Asia    Palestine  2021-04-26     319813.0      713.0
# AFG                Asia  Afghanistan  2022-02-22     172441.0      235.0
# IRN                Asia         Iran  2020-02-07          NaN        0.0
# YEM                Asia        Yemen  2023-06-25      11945.0        0.0
# PER       South America         Peru  2023-03-26    4490796.0      305.0
# SVK              Europe     Slovakia  2021-06-26     391531.0       41.0
# AND              Europe      Andorra  2023-01-25      47820.0        0.0
# LSO              Africa      Lesotho  2020-07-15        256.0       11.0
# ROU              Europe      Romania  2021-01-12     673271.0     1987.0
# OWID_OCE            NaN      Oceania  2020-08-24      27811.0      309.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ...

# %%
# Returns tuple of shape (Rows, columns)
print(df.shape)

# Returns size of dataframe
print(df.size)
# Out:
# (350108, 66)
# 23107128

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.120880e+05  3.404570e+05        3.391980e+05  2.905010e+05
# mean   6.683354e+06  9.601634e+03        9.637066e+03  8.602180e+04
# std    4.068903e+07  1.102769e+05        9.447784e+04  4.398873e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    8.090000e+03  0.000000e+00        2.860000e-01  1.270000e+02
# 50%    7.020500e+04  2.000000e+00        2.485700e+01  1.328000e+03
# 75%    7.409558e+05  2.640000e+02        4.978570e+02  1.192200e+04
# max    7.714071e+08  8.401961e+06        6.402036e+06  6.972139e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  340511.000000        339281.000000            312088.000000
# mean       85.511055            85.817071            101749.851259
# std       613.687971           559.130004            151265.689121
# min         0.000000             0.000000                 0.000000
# ...

# %%
# Information about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350108 entries, AFG to ZWE
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   continent                                   333435 non-null  object
#  1   location                                    350108 non-null  object
#  2   date                                        350108 non-null  object
#  3   total_cases                                 312088 non-null  float64
#  4   new_cases                                   340457 non-null  float64
#  5   new_cases_smoothed                          339198 non-null  float64
#  6   total_deaths                                290501 non-null  float64
#  7   new_deaths                                  340511 non-null  float64
#  8   new_deaths_smoothed                         339281 non-null  float64
# ...

# %%
# Columns labels of a Dataset
df.columns
# Out:
# Index(['continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
#drop the missing numbers
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# Drop NewCases, NewDeaths, NewRecovered rows from dataset1

df.drop(['new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
       'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
       'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
       'diabetes_prevalence', 'female_smokers', 'male_smokers',
       'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index', 'population',
       'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
       'excess_mortality', 'excess_mortality_cumulative_per_million'], 
              axis=1, inplace=True)

# Select random set of values from dataset1
df.sample(5)
# Out:
#               continent                    location        date  total_cases  \
# iso_code
# EGY              Africa                       Egypt  2022-07-27     514659.0
# TUV             Oceania                      Tuvalu  2020-06-06          NaN
# AND              Europe                     Andorra  2021-03-20      11431.0
# MAF       North America  Saint Martin (French part)  2023-09-19      12324.0
# VUT             Oceania                     Vanuatu  2022-05-21       8666.0
#
#           new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# iso_code
# EGY             0.0              35.143       24765.0         0.0
# TUV             0.0               0.000           NaN         0.0
# AND            38.0              29.000         113.0         0.0
# MAF             0.0               0.000          46.0         0.0
# VUT             0.0              66.429          14.0         0.0
#
#           new_deaths_smoothed  total_cases_per_million  ...  \
# ...

# %%
# Select both 'Age' and 'Salary' columns
subset_columns = df[['date','location','total_cases','total_deaths','new_cases','new_deaths','total_vaccinations']]
print(subset_columns)
# Out:
#                 date     location  total_cases  total_deaths  new_cases  \
# iso_code
# AFG       2020-01-03  Afghanistan          NaN           NaN        0.0
# AFG       2020-01-04  Afghanistan          NaN           NaN        0.0
# AFG       2020-01-05  Afghanistan          NaN           NaN        0.0
# AFG       2020-01-06  Afghanistan          NaN           NaN        0.0
# AFG       2020-01-07  Afghanistan          NaN           NaN        0.0
# ...              ...          ...          ...           ...        ...
# ZWE       2023-10-14     Zimbabwe     265808.0        5718.0        0.0
# ZWE       2023-10-15     Zimbabwe     265808.0        5718.0        0.0
# ZWE       2023-10-16     Zimbabwe     265808.0        5718.0        0.0
# ZWE       2023-10-17     Zimbabwe     265808.0        5718.0        0.0
# ZWE       2023-10-18     Zimbabwe     265808.0        5718.0        0.0
#
#           new_deaths  total_vaccinations
# iso_code
# ...

# %%
df_Africa= subset_columns.loc[subset_columns["total_deaths"]>=79000]
print(df_Africa.head())
# Out:
#                 date location  total_cases  total_deaths  new_cases  \
# iso_code
# OWID_AFR  2021-01-18   Africa    3283932.0       79224.0    25906.0
# OWID_AFR  2021-01-19   Africa    3306197.0       79964.0    22265.0
# OWID_AFR  2021-01-20   Africa    3330187.0       81160.0    23990.0
# OWID_AFR  2021-01-21   Africa    3360249.0       82103.0    30062.0
# OWID_AFR  2021-01-22   Africa    3387112.0       83109.0    26863.0
#
#           new_deaths  total_vaccinations
# iso_code
# OWID_AFR       601.0              7000.0
# OWID_AFR       740.0             10976.0
# OWID_AFR      1196.0             13163.0
# OWID_AFR       943.0             13163.0
# OWID_AFR      1006.0             16890.0

# %%
#df_Africa= subset_columns.loc[subset_columns["continent"]=="Africa"] 
#print(df_Africa.sample())
ke=subset_columns.loc[subset_columns["location"]=="Kenya"]
print(ke.sample())
# Out:
#                 date location  total_cases  total_deaths  new_cases  \
# iso_code
# KEN       2020-11-03    Kenya      56601.0        1027.0      724.0
#
#           new_deaths  total_vaccinations
# iso_code
# KEN             14.0                 NaN

# %%
## DATA VISUALISATION

# %%
plt.bar(x =subset_columns[subset_columns['location']=='Africa'] ,y= subset_columns['total_deaths'], height=50, color='green', edgecolor='blue')

plt.title("Total Deaths")

plt.ylabel('location')

plt.xlabel('total deaths')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plt.bar(x =subset_columns[subset_columns['location']=='Africa'] ,y= subset_columns['total_deaths'], height=50, color='green', edgecolor='blue')
#       3 plt.title("Total Deaths")
#       5 plt.ylabel('location')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2742, in bar(x, height, width, bottom, align, data, **kwargs)
#    2731 @_copy_docstring_and_deprecators(Axes.bar)
#    2732 def bar(
#    2733     x: float | ArrayLike,
#    (...)
#    2740     **kwargs,
#    2741 ) -> BarContainer:
# -> 2742     return gca().bar(
#    2743         x,
#    2744         height,
#    2745         width=width,
#    2746         bottom=bottom,
#    2747         align=align,
#    2748         **({"data": data} if data is not None else {}),
#    2749         **kwargs,
#    2750     )
#
# ...
